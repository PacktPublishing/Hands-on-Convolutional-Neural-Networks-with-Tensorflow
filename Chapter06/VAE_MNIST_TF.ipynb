# %% [markdown]
# # Variational AutoEncoder (MLP) Tensorflow
# Train a variational autoencoder with MNIST dataset
#
# #### References:
# * http://kvfrans.com/variational-autoencoders-explained/
# * https://github.com/kvfrans/variational-autoencoder
# * https://github.com/int8/VAE_tensorflow
# * http://int8.io/variational-autoencoder-in-tensorflow/
# * http://blog.fastforwardlabs.com/2016/08/22/under-the-hood-of-the-variational-autoencoder-in.html
# * http://blog.fastforwardlabs.com/2016/08/12/introducing-variational-autoencoders-in-prose-and.html
# * https://blog.keras.io/building-autoencoders-in-keras.html
# * https://jaan.io/what-is-variational-autoencoder-vae-tutorial/
# * https://arxiv.org/pdf/1606.05908.pdf
# * https://arxiv.org/pdf/1312.6114.pdf
# * http://wiseodd.github.io/techblog/2016/12/10/variational-autoencoder/
# * https://www.tensorflow.org/get_started/embedding_viz
# * https://www.youtube.com/watch?v=eBbEDRsCmv4
# * https://www.youtube.com/watch?v=bbOFvxbMIV0
# * https://www.youtube.com/watch?v=P78QYjWh5sM
# * https://github.com/normanheckscher/mnist-tensorboard-embeddings
# * http://projector.tensorflow.org/

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
os.environ["CUDA_VISIBLE_DEVICES"] = str(0)

SAVE_FOLDER='/tmp/vae_cnn'

# Delete directory if exist
if os.path.exists(SAVE_FOLDER):    
    os.system("rm -rf " + SAVE_FOLDER)

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# Learning parameters
start_lr = 0.001
num_epoch = 200
batch_size = 100
# Out:
# /Users/leonardo_a/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-466654d2552d>:14: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/leonardo_a/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/leonardo_a/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/leonardo_a/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/leonardo_a/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/leonardo_a/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
from models import VAE_CNN
model = VAE_CNN(latent_size = 20)
model_in = model.input
model_out = model.output
model_out_flat = model.output_flat
z_mean = model.z_mean
z_stddev = model.z_stddev

# %% [markdown]
# ### Define loss

# %%
with tf.name_scope("VAE_LOSS"):
    # Binary cross entropy
    generation_loss = -tf.reduce_sum(
        model_in * tf.log(1e-8 + model_out_flat) + (1-model_in) * tf.log(1e-8 + 1 - model_out_flat),1)
    
    # L2/L1 Loss (Works, but sometimes you my get a NaN)
    #generation_loss = tf.norm(model_in-model_out_flat, ord=1)
    #generation_loss = tf.nn.l2_loss(model_in-model_out_flat)
    
    # KL Loss
    latent_loss = 0.5 * tf.reduce_sum(
        tf.square(z_mean) + tf.square(z_stddev) - tf.log(tf.square(z_stddev)) - 1,1)
    
    # Merge the losses
    loss = tf.reduce_mean(generation_loss + latent_loss)

# %% [markdown]
# ### Define the Solver

# %%
# Solver configuration
# Solver configuration
# Get ops to update moving_mean and moving_variance from batch_norm
# Reference: https://www.tensorflow.org/api_docs/python/tf/contrib/layers/batch_norm
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.name_scope("Solver"):
    # Stuff for learning rate decay
    global_step = tf.Variable(0, trainable=False)
    starter_learning_rate = start_lr
    # decay every 10000 steps with a base of 0.96
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
                                               1000, 0.9, staircase=True)
    # Optimizer
    train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

# %% [markdown]
# ### Build Graph

# %%
init = tf.global_variables_initializer()

# Avoid allocating the whole memory
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

#sess = tf.Session()
sess.run(init)

# %% [markdown]
# ### Add some tensors to observe on Tensorboard

# %%
tf.summary.image("input_image", model.image_in, 4)
tf.summary.image("output_image", model_out, 4)
tf.summary.scalar("global_step", global_step)
tf.summary.scalar("learning_rate", learning_rate)
tf.summary.scalar("loss", loss)

merged_summary = tf.summary.merge_all()
summary_writer = tf.summary.FileWriter(SAVE_FOLDER, graph=tf.get_default_graph())

# Create saver object
saver = tf.train.Saver()

# %% [markdown]
# ### Train

# %%
# For each epoch
for epoch in range(num_epoch):
    for i in range(int(mnist.train.num_examples / batch_size)):
        # Get batch of 50 images
        batch = mnist.train.next_batch(50)

        # Train actually here (Also get loss value)    
        _, val_loss = sess.run((train_step, loss), feed_dict={model_in:batch[0]})
        
        # write logs at every iteration
        summary = sess.run(merged_summary, feed_dict={model_in:batch[0]})
        summary_writer.add_summary(summary, epoch * batch_size + i)
        
    print('Epoch: %d/%d loss:%d' % (epoch, num_epoch, val_loss))
    
    # Save checkpoint after each epoch
    if not os.path.exists(SAVE_FOLDER):
        os.makedirs(SAVE_FOLDER)
    checkpoint_path = os.path.join(SAVE_FOLDER, "model")
    filename = saver.save(sess, checkpoint_path, global_step=epoch)
    print("Model saved in file: %s" % filename)
# Out:
# Epoch: 0/200 loss:139
# Model saved in file: /tmp/vae_cnn/model-0
# Epoch: 1/200 loss:119
# Model saved in file: /tmp/vae_cnn/model-1
# Epoch: 2/200 loss:114
# Model saved in file: /tmp/vae_cnn/model-2
# Epoch: 3/200 loss:117
# Model saved in file: /tmp/vae_cnn/model-3
# Epoch: 4/200 loss:112
# Model saved in file: /tmp/vae_cnn/model-4
# Epoch: 5/200 loss:110
# Model saved in file: /tmp/vae_cnn/model-5
# Epoch: 6/200 loss:112
# Model saved in file: /tmp/vae_cnn/model-6
# Epoch: 7/200 loss:109
# Model saved in file: /tmp/vae_cnn/model-7
# Epoch: 8/200 loss:110
# Model saved in file: /tmp/vae_cnn/model-8
# Epoch: 9/200 loss:109
# Model saved in file: /tmp/vae_cnn/model-9
# Epoch: 10/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-10
# Epoch: 11/200 loss:107
# Model saved in file: /tmp/vae_cnn/model-11
# Epoch: 12/200 loss:110
# Model saved in file: /tmp/vae_cnn/model-12
# Epoch: 13/200 loss:110
# Model saved in file: /tmp/vae_cnn/model-13
# Epoch: 14/200 loss:111
# Model saved in file: /tmp/vae_cnn/model-14
# Epoch: 15/200 loss:109
# Model saved in file: /tmp/vae_cnn/model-15
# Epoch: 16/200 loss:104
# Model saved in file: /tmp/vae_cnn/model-16
# Epoch: 17/200 loss:99
# Model saved in file: /tmp/vae_cnn/model-17
# Epoch: 18/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-18
# Epoch: 19/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-19
# Epoch: 20/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-20
# Epoch: 21/200 loss:106
# Model saved in file: /tmp/vae_cnn/model-21
# Epoch: 22/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-22
# Epoch: 23/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-23
# Epoch: 24/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-24
# Epoch: 25/200 loss:106
# Model saved in file: /tmp/vae_cnn/model-25
# Epoch: 26/200 loss:109
# Model saved in file: /tmp/vae_cnn/model-26
# Epoch: 27/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-27
# Epoch: 28/200 loss:104
# Model saved in file: /tmp/vae_cnn/model-28
# Epoch: 29/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-29
# Epoch: 30/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-30
# Epoch: 31/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-31
# Epoch: 32/200 loss:106
# Model saved in file: /tmp/vae_cnn/model-32
# Epoch: 33/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-33
# Epoch: 34/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-34
# Epoch: 35/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-35
# Epoch: 36/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-36
# Epoch: 37/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-37
# Epoch: 38/200 loss:100
# Model saved in file: /tmp/vae_cnn/model
200 loss:100
# Model saved in file: /tmp/vae_cnn/model-125
# Epoch: 126/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-126
# Epoch: 127/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-127
# Epoch: 128/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-128
# Epoch: 129/200 loss:104
# Model saved in file: /tmp/vae_cnn/model-129
# Epoch: 130/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-130
# Epoch: 131/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-131
# Epoch: 132/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-132
# Epoch: 133/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-133
# Epoch: 134/200 loss:95
# Model saved in file: /tmp/vae_cnn/model-134
# Epoch: 135/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-135
# Epoch: 136/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-136
# Epoch: 137/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-137
# Epoch: 138/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-138
# Epoch: 139/200 loss:108
# Model saved in file: /tmp/vae_cnn/model-139
# Epoch: 140/200 loss:99
# Model saved in file: /tmp/vae_cnn/model-140
# Epoch: 141/200 loss:108
# Model saved in file: /tmp/vae_cnn/model-141
# Epoch: 142/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-142
# Epoch: 143/200 loss:97
# Model saved in file: /tmp/vae_cnn/model-143
# Epoch: 144/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-144
# Epoch: 145/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-145
# Epoch: 146/200 loss:97
# Model saved in file: /tmp/vae_cnn/model-146
# Epoch: 147/200 loss:99
# Model saved in file: /tmp/vae_cnn/model-147
# Epoch: 148/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-148
# Epoch: 149/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-149
# Epoch: 150/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-150
# Epoch: 151/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-151
# Epoch: 152/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-152
# Epoch: 153/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-153
# Epoch: 154/200 loss:96
# Model saved in file: /tmp/vae_cnn/model-154
# Epoch: 155/200 loss:97
# Model saved in file: /tmp/vae_cnn/model-155
# Epoch: 156/200 loss:94
# Model saved in file: /tmp/vae_cnn/model-156
# Epoch: 157/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-157
# Epoch: 158/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-158
# Epoch: 159/200 loss:96
# Model saved in file: /tmp/vae_cnn/model-159
# Epoch: 160/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-160
# Epoch: 161/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-161
# Epoch: 162/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-162
# Epoch: 163/200 loss:99
# Model saved in file: /tmp/vae_cnn/model-163
# Epoch: 164/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-164
# Epoch: 165/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-165
# Epoch: 166/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-166
# Epoch: 167/200 loss:104
# Model saved in file: /tmp/vae_cnn/model-167
# Epoch: 168/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-168
# Epoch: 169/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-169
# Epoch: 170/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-170
# Epoch: 171/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-171
# Epoch: 172/200 loss:104
# Model saved in file: /tmp/vae_cnn/model-172
# Epoch: 173/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-173
# Epoch: 174/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-174
# Epoch: 175/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-175
# Epoch: 176/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-176
# Epoch: 177/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-177
# Epoch: 178/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-178
# Epoch: 179/200 loss:103
# Model saved in file: /tmp/vae_cnn/model-179
# Epoch: 180/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-180
# Epoch: 181/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-181
# Epoch: 182/200 loss:95
# Model saved in file: /tmp/vae_cnn/model-182
# Epoch: 183/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-183
# Epoch: 184/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-184
# Epoch: 185/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-185
# Epoch: 186/200 loss:99
# Model saved in file: /tmp/vae_cnn/model-186
# Epoch: 187/200 loss:100
# Model saved in file: /tmp/vae_cnn/model-187
# Epoch: 188/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-188
# Epoch: 189/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-189
# Epoch: 190/200 loss:98
# Model saved in file: /tmp/vae_cnn/model-190
# Epoch: 191/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-191
# Epoch: 192/200 loss:102
# Model saved in file: /tmp/vae_cnn/model-192
# Epoch: 193/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-193
# Epoch: 194/200 loss:105
# Model saved in file: /tmp/vae_cnn/model-194
# Epoch: 195/200 loss:101
# Model saved in file: /tmp/vae_cnn/model-195
# Epoch: 196/200 loss:106
# Model saved in file: /tmp/vae_cnn/model-196
# Epoch: 197/200 loss:104
# Model saved in file: /tmp/vae_cnn/model-197
# Epoch: 198/200 loss:95
# Model saved in file: /tmp/vae_cnn/model-198
# Epoch: 199/200 loss:106
# Model saved in file: /tmp/vae_cnn/model-199
